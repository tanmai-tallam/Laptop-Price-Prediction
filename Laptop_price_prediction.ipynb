# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmai-tallam/Laptop-Price-Prediction/blob/main/Laptop_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 131543: invalid continuation byte

# %%
df=pd.read_csv("/content/drive/MyDrive/Adverk AI/TANMAI TALLAM/Laptop Price Prediction/laptop_price.csv",encoding="latin")
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 28

# %%
df.drop_duplicates(inplace=True)

# %%
df['Price_euros']
# Out:
# 0       1339.69
# 1        898.94
# 2        575.00
# 3       2537.45
# 4       1803.60
#          ...
# 1270     638.00
# 1271    1499.00
# 1272     229.00
# 1273     764.00
# 1274     369.00
# Name: Price_euros, Length: 1275, dtype: float64

# %%
df['Price']=round(df['Price_euros']*89.2834).astype('int')

# %%
df.sample(3)
# Out:
#        Company           Product            TypeName  Inches  \
# 994       Dell     Inspiron 5378  2 in 1 Convertible    13.3
# 1268        HP  Stream 11-Y000na             Netbook    11.6
# 575   Mediacom     SmartBook 141            Notebook    14.0
#
#                      ScreenResolution                                   Cpu  \
# 994   Full HD / Touchscreen 1920x1080            Intel Core i5 7200U 2.5GHz
# 1268                         1366x768  Intel Celeron Dual Core N3060 1.6GHz
# 575                 Full HD 1920x1080           Intel Atom x5-Z8350 1.44GHz
#
#       Ram              Memory                    Gpu       OpSys  Weight  \
# 994   8GB           256GB SSD  Intel HD Graphics 620  Windows 10  1.68kg
# 1268  2GB  32GB Flash Storage  Intel HD Graphics 400  Windows 10  1.17kg
# 575   4GB            32GB SSD      Intel HD Graphics  Windows 10   1.4kg
#
#       Price_euros  Price
# 994         889.0  79373
# 1268        209.0  18660
# 575         249.0  22232

# %%
df.drop(columns=['Price_euros'],inplace=True)

# %%
df.sample(3)
# Out:
#      Company                             Product  TypeName  Inches  \
# 1016      HP                         ProBook 450  Notebook    15.6
# 140     Acer                            Aspire 5  Notebook    17.3
# 332     Asus  UX510UX-CN269T (i7-7500U/8GB/256GB  Notebook    14.0
#
#                  ScreenResolution                         Cpu  Ram  \
# 1016                     1366x768  Intel Core i3 7100U 2.4GHz  4GB
# 140   IPS Panel Full HD 1920x1080  Intel Core i3 7130U 2.7GHz  4GB
# 332             Full HD 1920x1080  Intel Core i7 7500U 2.7GHz  8GB
#
#                     Memory                    Gpu       OpSys  Weight   Price
# 1016             256GB SSD  Intel HD Graphics 620  Windows 10  2.04kg   68747
# 140                1TB HDD   Nvidia GeForce MX130  Windows 10     3kg   58481
# 332   256GB SSD +  1TB HDD  Intel HD Graphics 620  Windows 10     2kg  119104

# %%
# EDA : Exploratory Data Analysis
# 1.Univariate Data Analysis
# 2.Bivariate Analysis (wrt Price column)

# %%
# Company

# %%
df['Company'].value_counts()
# Out:
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
9+7+7+6+4+4+3+3+3+3+2
# Out:
# 51

# %%
51/1303
# Out:
# 0.039140445126630855

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Company'].value_counts()[0:8].plot(kind='bar')
# Out:
# <Axes: >

# %%
df=df[df.groupby('Company')['Company'].transform('count')>10]

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                    1366x768
# 1273                                    1366x768
# 1274                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1270            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1271            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1272  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1273            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  119612
# 1           Intel HD Graphics 6000       macOS  1.34kg   80260
# 2            Intel HD Graphics 620       No OS  1.86kg   51338
# 3               AMD Radeon Pro 455       macOS  1.83kg  226552
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  161032
# ...                            ...         ...     ...     ...
# 1270         Intel HD Graphics 520  Windows 10   1.8kg   56963
# 1271         Intel HD Graphics 520  Windows 10   1.3kg  133836
# 1272             Intel HD Graphics  Windows 10   1.5kg   20446
# 1273            AMD Radeon R5 M330  Windows 10  2.19kg   68213
# 1274             Intel HD Graphics  Windows 10   2.2kg   32946
#
# [1224 rows x 12 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df['Company'].value_counts()
# Out:
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: Company, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Product'].value_counts()
# Out:
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Legion Y520-15IKBN                     19
# Vostro 3568                            19
#                                        ..
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# Portege X30-D-10L                       1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: Product, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)
# Out:
# <ipython-input-250-4bcf6fa0a033>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Product'],inplace=True)

# %%
df.sample()
# Out:
#     Company            TypeName  Inches                     ScreenResolution  \
# 932    Asus  2 in 1 Convertible    15.6  4K Ultra HD / Touchscreen 3840x2160
#
#                             Cpu   Ram                Memory  \
# 932  Intel Core i7 7500U 2.7GHz  16GB  512GB SSD +  2TB HDD
#
#                          Gpu       OpSys Weight   Price
# 932  Nvidia GeForce GTX 950M  Windows 10  2.3kg  160621

# %%
# TypeName
df['TypeName'].value_counts()
# Out:
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: TypeName, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company  TypeName  Inches   ScreenResolution                         Cpu  \
# 260  Lenovo  Notebook    15.6  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
#
#      Ram     Memory                     Gpu       OpSys  Weight  Price
# 260  8GB  256GB SSD  Intel UHD Graphics 620  Windows 10  2.05kg  78569

# %%
df['Inches'].value_counts()
# Out:
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: Inches, dtype: int64

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.displot(df['Inches'],kde=True)
plt.show()

# %%
sns.barplot(x=df['Inches'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company  TypeName  Inches ScreenResolution                         Cpu  \
# 702    Acer  Notebook    15.6         1366x768  Intel Core i5 7200U 2.5GHz
#
#      Ram     Memory                    Gpu       OpSys Weight  Price
# 702  4GB  500GB HDD  Intel HD Graphics 620  Windows 10  2.4kg  49909

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 3200x1800                       2
# 1920x1080                                          2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / Full HD 1920x1080                    1
# Name: ScreenResolution, dtype: int64

# %%
# X_res
# Y_res
# Touchscreen
# IPS

# %%
a="IPS Panel 4K Ultra HD / Touchscreen 3840x2160"

# %%
a.split()
# Out:
# ['IPS', 'Panel', '4K', 'Ultra', 'HD', '/', 'Touchscreen', '3840x2160']

# %%
a.split()[-1]
# Out:
# '3840x2160'

# %%
a.split()[-1].split('x')
# Out:
# ['3840', '2160']

# %%
a.split()[-1].split('x')[0]
# Out:
# '3840'

# %%
a.split()[-1].split('x')[1]
# Out:
# '2160'

# %%
(lambda a:a.split()[-1].split('x')[1])("IPS Panel 4K Ultra HD / Touchscreen 3840x2160")
# Out:
# '2160'

# %%
df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')
# Out:
# <ipython-input-271-40f364c1e3d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
# <ipython-input-271-40f364c1e3d3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')

# %%
df.sample(3)
# Out:
#     Company            TypeName  Inches  \
# 454      HP  2 in 1 Convertible    13.3
# 974    Dell  2 in 1 Convertible    15.6
# 731    Dell            Notebook    13.3
#
#                                   ScreenResolution  \
# 454  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 974      IPS Panel Full HD / Touchscreen 1920x1080
# 731                                       1366x768
#
#                             Cpu  Ram     Memory                     Gpu  \
# 454  Intel Core i7 8550U 1.8GHz  8GB  512GB SSD  Intel UHD Graphics 620
# 974  Intel Core i3 6100U 2.3GHz  4GB    1TB HDD   Intel HD Graphics 520
# 731    Intel Core i3 6006U 2GHz  4GB  500GB HDD   Intel HD Graphics 520
#
#           OpSys  Weight   Price  X_res  Y_res
# 454  Windows 10  1.29kg  178478   3840   2160
# 974  Windows 10  2.08kg   71069   1920   1080
# 731  Windows 10  1.65kg   75802   1366    768

# %%
a="IPS Panel 4K Ultra HD / Touchscreen 3840x2160"

# %%
(lambda a:1 if "Touchscreen" in a else 0)("IPS Panel 4K Ultra HD / Touchscreen 3840x2160")
# Out:
# 1

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if "Touchscreen" in a else 0)
df['IPS']=df['ScreenResolution'].apply(lambda a:1 if "IPS" in a else 0)
# Out:
# <ipython-input-275-2c62828ec996>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if "Touchscreen" in a else 0)
# <ipython-input-275-2c62828ec996>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IPS']=df['ScreenResolution'].apply(lambda a:1 if "IPS" in a else 0)

# %%
df.sample(15)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 1098    Dell            Notebook    15.6                Full HD 1920x1080
# 1115      HP            Notebook    15.6                         1366x768
# 712   Lenovo  2 in 1 Convertible    14.0  Full HD / Touchscreen 1920x1080
# 220       HP            Notebook    15.6                Full HD 1920x1080
# 1133    Dell            Notebook    15.6                Full HD 1920x1080
# 816     Asus            Notebook    15.6                         1366x768
# 134     Asus              Gaming    17.3                Full HD 1920x1080
# 831   Lenovo            Notebook    15.6                Full HD 1920x1080
# 288     Dell         Workstation    17.3                Full HD 1920x1080
# 435      MSI              Gaming    15.6                Full HD 1920x1080
# 1053    Dell           Ultrabook    12.5                         1366x768
# 218     Asus            Notebook    15.6                Full HD 1920x1080
# 262     Asus              Gaming    17.3                Full HD 1920x1080
# 427   Lenovo            Notebook    17.3                         1600x900
# 84        HP           Ultrabook    15.6      IPS Panel Full HD 1920x1080
#
#                                        Cpu   Ram                Memory  \
# 1098            Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 1115            Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 712             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 220             Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
# 1133            Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 816   Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 134            Intel Core i5 7300HQ 2.5GHz   8GB  128GB SSD +  1TB HDD
# 831               Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 288            Intel Core i7 7820HQ 2.9GHz  16GB             256GB SSD
# 435            Intel Core i5 7300HQ 2.5GHz   8GB             256GB SSD
# 1053            Intel Core i3 6100U 2.3GHz   4GB             500GB HDD
# 218             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 262                    AMD Ryzen 1700 3GHz  16GB  256GB SSD +  1TB HDD
# 427              AMD A6-Series 9220 2.5GHz   8GB               1TB HDD
# 84              Intel Core i7 8550U 1.8GHz   8GB             256GB SSD
#
#                            Gpu       OpSys  Weight   Price  X_res  Y_res  \
# 1098      Nvidia GeForce 940MX  Windows 10  2.18kg   90167   1920   1080
# 1115     Intel HD Graphics 520       No OS   2.1kg   42587   1366    768
# 712      Intel HD Graphics 620  Windows 10   1.7kg   89194   1920   1080
# 220        AMD FirePro W4190M   Windows 10   1.9kg  113301   1920   1080
# 1133   Nvidia GeForce GT 940MX       Linux  1.98kg   79910   1920   1080
# 816      Intel HD Graphics 505  Windows 10     2kg   40088   1366    768
# 134    Nvidia GeForce GTX 1050  Windows 10     3kg   83748   1920   1080
# 831         AMD Radeon R5 M430       No OS   2.2kg   42767   1920   1080
# 288        Nvidia Quadro M1200  Windows 10  3.42kg  257570   1920   1080
# 435    Nvidia GeForce GTX 1050  Windows 10   2.2kg   91760   1920   1080
# 1053     Intel HD Graphics 520   Windows 7   1.5kg  101350   1366    768
# 218      Nvidia GeForce 920MX   Windows 10     2kg   68659   1920   1080
# 262          AMD Radeon RX 580  Windows 10   3.2kg  138300   1920   1080
# 427              AMD Radeon R4  Windows 10   2.8kg   46338   1600    900
# 84    Nvidia GeForce GTX 940MX  Windows 10  1.83kg   62409   1920   1080
#
#       Touchscreen  IPS
# 1098            0    0
# 1115            0    0
# 712             1    0
# 220             0    0
# 1133            0    0
# 816             0    0
# 134             0    0
# 831             0    0
# 288             0    0
# 435             0    0
# 1053            0    0
# 218             0    0
# 262             0    0
# 427             0    0
# 84              0    1

# %%
df.drop(columns=['ScreenResolution'],inplace=True)
# Out:
# <ipython-input-277-5a8c076be408>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches                         Cpu  Ram     Memory  \
# 330    Dell  Notebook    15.6  Intel Core i5 8250U 1.6GHz  8GB  256GB SSD
#
#                       Gpu       OpSys Weight   Price  X_res  Y_res  \
# 330  Nvidia GeForce 940MX  Windows 10    2kg  102029   1920   1080
#
#      Touchscreen  IPS
# 330            0    0

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: Cpu, Length: 111, dtype: int64

# %%
a="Intel Core i5 7200U 2.5GHz"

# %%
a.split()
# Out:
# ['Intel', 'Core', 'i5', '7200U', '2.5GHz']

# %%
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
" ".join(a.split()[0:3])
# Out:
# 'Intel Core i5'

# %%
(lambda a:" ".join(a.split()[0:3]))("Intel Core i5 7200U 2.5GHz")
# Out:
# 'Intel Core i5'

# %%
df['Cpu']=df['Cpu'].apply(lambda a:" ".join(a.split()[0:3]))
# Out:
# <ipython-input-285-a7ccd9163b7f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(lambda a:" ".join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom x5-Z8350           1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: Cpu, dtype: int64

# %%
def fetch_processor(text):
    if text=="Intel Core i7" or text=="Intel Core i5" or text=="Intel Core i3" or text=="Intel Core M":
        return text
    elif text.split()[0]=="Intel":
        return " ".join(text.split()[0:2])
    else:
        if text[4]=="E":
            return "AMD E-Series"
        elif text[4]=="F":
            return "AMD F-Series"
        elif text[4]=="A":
            return "AMD A-Series"
        else:
            return "AMD Ryzen Series"

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor)
# Out:
# <ipython-input-288-e879aaac7dc4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(fetch_processor)

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i7       493
# Intel Core i5       411
# Intel Core i3       134
# Intel Celeron        71
# AMD A-Series         45
# Intel Pentium        30
# Intel Core M         16
# AMD E-Series          9
# Intel Atom            5
# AMD Ryzen Series      4
# Intel Xeon            4
# AMD F-Series          2
# Name: Cpu, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Cpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample(3)
# Out:
#      Company            TypeName  Inches            Cpu  Ram  \
# 1141  Lenovo              Gaming    15.6  Intel Core i5  8GB
# 1047      HP             Netbook    12.5  Intel Core i5  4GB
# 1077  Lenovo  2 in 1 Convertible    10.1     Intel Atom  4GB
#
#                   Memory                      Gpu       OpSys  Weight   Price  \
# 1141             1TB HDD  Nvidia GeForce GTX 1050  Windows 10   2.4kg   73123
# 1047           128GB SSD    Intel HD Graphics 520   Windows 7   2.4kg  142764
# 1077  64GB Flash Storage    Intel HD Graphics 400  Windows 10  0.69kg   42767
#
#       X_res  Y_res  Touchscreen  IPS
# 1141   1920   1080            0    1
# 1047   1366    768            0    0
# 1077   1920   1200            1    1

# %%
df['Ram']
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1219     4GB
# 1220    16GB
# 1221     2GB
# 1222     6GB
# 1223     4GB
# Name: Ram, Length: 1224, dtype: object

# %%
a="16GB"
a.replace("GB","")
# Out:
# '16'

# %%
(lambda a:a.replace("GB",""))("16GB")
# Out:
# '16'

# %%
df['Ram']=df['Ram'].apply(lambda a:a.replace("GB","")).astype('int')
# Out:
# <ipython-input-296-31ec40dfd046>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram']=df['Ram'].apply(lambda a:a.replace("GB","")).astype('int')

# %%
df['Ram'].value_counts()
# Out:
# 8     595
# 4     351
# 16    186
# 6      34
# 12     25
# 32     15
# 2      14
# 24      3
# 64      1
# Name: Ram, dtype: int64

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#   Company  TypeName  Inches            Cpu  Ram     Memory  \
# 2      HP  Notebook    15.6  Intel Core i5    8  256GB SSD
#
#                      Gpu  OpSys  Weight  Price  X_res  Y_res  Touchscreen  IPS
# 2  Intel HD Graphics 620  No OS  1.86kg  51338   1920   1080            0    0

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: Gpu, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda a:" ".join(a.split()[0:2]))
# Out:
# <ipython-input-302-837b199691d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu']=df['Gpu'].apply(lambda a:" ".join(a.split()[0:2]))

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD          586
# Nvidia GeForce    353
# AMD Radeon        166
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# AMD R4              1
# Nvidia GTX          1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: Gpu, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Gpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#   Company   TypeName  Inches            Cpu  Ram     Memory         Gpu  \
# 4   Apple  Ultrabook    13.3  Intel Core i5    8  256GB SSD  Intel Iris
#
#    OpSys  Weight   Price  X_res  Y_res  Touchscreen  IPS
# 4  macOS  1.37kg  161032   2560   1600            0    1

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: OpSys, dtype: int64

# %%
def os(text):
    if text=="Windows 10" or text=="Windows 10 S":
        return "Windows 10"
    elif text=="Windows 7":
        return text
    elif text=="macOS" and text=="Mac OS X":
        return "MacOS"
    elif text=="No OS":
        return "No OS"
    else:
        return "Chrome OS/Linux/Android"

# %%
df['OpSys']=df['OpSys'].apply(os)
# Out:
# <ipython-input-309-1a89346e0b11>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OpSys']=df['OpSys'].apply(os)

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10                 1013
# Chrome OS/Linux/Android     103
# No OS                        63
# Windows 7                    45
# Name: OpSys, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram     Memory             Gpu  \
# 602    Dell  Notebook    15.6  Intel Core i7    8  256GB SSD  Nvidia GeForce
#
#           OpSys Weight   Price  X_res  Y_res  Touchscreen  IPS
# 602  Windows 10    2kg  162496   1920   1080            0    0

# %%
df['Weight']=df['Weight'].apply(lambda a:a.replace("kg","")).astype('float')
# Out:
# <ipython-input-314-8388be4cadc2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=df['Weight'].apply(lambda a:a.replace("kg","")).astype('float')

# %%
df['Weight'].describe()
# Out:
# count    1224.000000
# mean        2.063204
# std         0.663863
# min         0.690000
# 25%         1.597500
# 50%         2.060000
# 75%         2.320000
# max         4.700000
# Name: Weight, dtype: float64

# %%
sns.displot(df['Weight'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company TypeName  Inches            Cpu  Ram                Memory  \
# 745    Asus   Gaming    17.3  Intel Core i7   16  256GB SSD +  1TB HDD
#
#                 Gpu       OpSys  Weight   Price  X_res  Y_res  Touchscreen  \
# 745  Nvidia GeForce  Windows 10     4.3  209816   1920   1080            0
#
#      IPS
# 745    1

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  512GB SSD             1
# 512GB SSD +  256GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 64GB SSD                           1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
# SSD
# HDD
# SSD + HDD
# Flash Storage
# Hybrid
# SSD + SSD
# Flash Storage + HDD
# HDD + HDD
# SSD + Hybrid

# Due to the sheer complexity and different variants, we will delete the memory column

# %%
df.drop(columns=['Memory'],inplace=True)
# Out:
# <ipython-input-321-8cab1fd6fcc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Memory'],inplace=True)

# %%
df.sample()
# Out:
#     Company            TypeName  Inches            Cpu  Ram       Gpu  \
# 690      HP  2 in 1 Convertible    13.3  Intel Core i5    8  Intel HD
#
#           OpSys  Weight  Price  X_res  Y_res  Touchscreen  IPS
# 690  Windows 10    1.58  74694   1366    768            1    1

# %%
df.corr(numeric_only=True)
# Out:
#                Inches       Ram    Weight     Price     X_res     Y_res  \
# Inches       1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram          0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight       0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# Price        0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# X_res       -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# Y_res       -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# Touchscreen -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# IPS         -0.104090  0.223322  0.038753  0.289225  0.283969  0.294360
#
#              Touchscreen       IPS
# Inches         -0.359497 -0.104090
# Ram             0.094037  0.223322
# Weight         -0.291506  0.038753
# Price           0.161443  0.289225
# X_res           0.320954  0.283969
# Y_res           0.317174  0.294360
# Touchscreen     1.000000  0.154500
# IPS             0.154500  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),cmap="winter")
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# Touchscreen    0.161443
# IPS            0.289225
# Name: Price, dtype: float64

# %%
df.sample(2)
# Out:
#     Company            TypeName  Inches            Cpu  Ram       Gpu  \
# 994  Lenovo  2 in 1 Convertible    15.6  Intel Core i7    4  Intel HD
# 317    Acer            Notebook    15.6  Intel Core i5    6  Intel HD
#
#           OpSys  Weight  Price  X_res  Y_res  Touchscreen  IPS
# 994  Windows 10    1.80  75623   1920   1080            1    1
# 317  Windows 10    2.23  49017   1366    768            0    0

# %%
# pixel density
df['ppi']=round(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches'],2)
# Out:
# <ipython-input-327-3138324f6b28>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ppi']=round(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches'],2)

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# Touchscreen    0.161443
# IPS            0.289225
# ppi            0.483787
# Name: Price, dtype: float64

# %%
df.drop(columns=['X_res','Y_res','Inches'],inplace=True)
# Out:
# <ipython-input-329-d7ec33861cbb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['X_res','Y_res','Inches'],inplace=True)

# %%
df['ppi'].value_counts()
# Out:
# 141.21    419
# 100.45    195
# 127.34    131
# 157.35    122
# 165.63    100
# 111.94     42
# 135.09     28
# 176.23     25
# 276.05     25
# 282.42     23
# 106.11     22
# 209.80     18
# 125.37      9
# 117.83      8
# 331.26      7
# 226.98      6
# 226.42      6
# 254.67      5
# 127.68      4
# 224.17      4
# 158.48      4
# 220.53      4
# 169.78      2
# 220.84      2
# 316.97      2
# 352.47      2
# 90.58       2
# 119.72      1
# 189.91      1
# 107.99      1
# 111.14      1
# 194.95      1
# 234.98      1
# 146.86      1
# Name: ppi, dtype: int64

# %%
sns.displot(x=df['ppi'],kde=True)

# %%
sns.scatterplot(x=df['ppi'],y=df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company            TypeName            Cpu  Ram       Gpu       OpSys  \
# 380  Lenovo  2 in 1 Convertible  Intel Core i7   16  Intel HD  Windows 10
#
#      Weight   Price  Touchscreen  IPS    ppi
# 380    1.42  224012            1    0  209.8

# %%
df['Touchscreen'].value_counts()
# Out:
# 0    1055
# 1     169
# Name: Touchscreen, dtype: int64

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['IPS'].value_counts()
# Out:
# 0    885
# 1    339
# Name: IPS, dtype: int64

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company   TypeName            Cpu  Ram             Gpu       OpSys  \
# 813  Lenovo  Ultrabook  Intel Core i7    8  Nvidia GeForce  Windows 10
#
#      Weight   Price  Touchscreen  IPS     ppi
# 813    1.96  169906            0    1  157.35

# %%
df['Price'].describe()
# Out:
# count      1224.000000
# mean     100406.710784
# std       59806.561210
# min       15535.000000
# 25%       54722.250000
# 50%       87408.000000
# 75%      131916.500000
# max      437399.000000
# Name: Price, dtype: float64

# %%
sns.displot(df['Price'],kind='kde')

# %%
sns.displot(np.log(df['Price']),kind='kde')

# %%
df.sample()
# Out:
#     Company  TypeName            Cpu  Ram       Gpu       OpSys  Weight  \
# 780    Dell  Notebook  Intel Core i5    4  Intel HD  Windows 10    1.76
#
#      Price  Touchscreen  IPS     ppi
# 780  67409            0    0  111.94

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=13)

# %%
X.shape
# Out:
# (1224, 10)

# %%
X_train.shape
# Out:
# (1040, 10)

# %%
X_test.shape
# Out:
# (184, 10)

# %%
0.85*1224
# Out:
# 1040.3999999999999

# %%
X
# Out:
#      Company            TypeName            Cpu  Ram         Gpu  \
# 0      Apple           Ultrabook  Intel Core i5    8  Intel Iris
# 1      Apple           Ultrabook  Intel Core i5    8    Intel HD
# 2         HP            Notebook  Intel Core i5    8    Intel HD
# 3      Apple           Ultrabook  Intel Core i7   16  AMD Radeon
# 4      Apple           Ultrabook  Intel Core i5    8  Intel Iris
# ...      ...                 ...            ...  ...         ...
# 1219  Lenovo  2 in 1 Convertible  Intel Core i7    4    Intel HD
# 1220  Lenovo  2 in 1 Convertible  Intel Core i7   16    Intel HD
# 1221  Lenovo            Notebook  Intel Celeron    2    Intel HD
# 1222      HP            Notebook  Intel Core i7    6  AMD Radeon
# 1223    Asus            Notebook  Intel Celeron    4    Intel HD
#
#                         OpSys  Weight  Touchscreen  IPS     ppi
# 0     Chrome OS/Linux/Android    1.37            0    1  226.98
# 1     Chrome OS/Linux/Android    1.34            0    0  127.68
# 2                       No OS    1.86            0    0  141.21
# 3     Chrome OS/Linux/Android    1.83            0    1  220.53
# 4     Chrome OS/Linux/Android    1.37            0    1  226.98
# ...                       ...     ...          ...  ...     ...
# 1219               Windows 10    1.80            1    1  157.35
# 1220               Windows 10    1.30            1    1  276.05
# 1221               Windows 10    1.50            0    0  111.94
# 1222               Windows 10    2.19            0    0  100.45
# 1223               Windows 10    2.20            0    0  100.45
#
# [1224 rows x 10 columns]

# %%
X_train
# Out:
#     Company            TypeName            Cpu  Ram             Gpu  \
# 682    Dell            Notebook  Intel Core i5    8        Intel HD
# 181    Dell            Notebook  Intel Core i7   16  Nvidia GeForce
# 761  Lenovo  2 in 1 Convertible  Intel Core i7    8        Intel HD
# 998      HP            Notebook  Intel Core i5    8        Intel HD
# 617    Acer            Notebook  Intel Core i3    4        Intel HD
# ..      ...                 ...            ...  ...             ...
# 866      HP           Ultrabook   Intel Core M    8        Intel HD
# 742    Acer            Notebook  Intel Core i3    4        Intel HD
# 74   Lenovo            Notebook  Intel Core i5    8        Intel HD
# 176    Dell            Notebook  Intel Core i7   16      AMD Radeon
# 338    Dell           Ultrabook  Intel Core i7   16       Intel UHD
#
#                        OpSys  Weight  Touchscreen  IPS     ppi
# 682  Chrome OS/Linux/Android    1.98            0    0  141.21
# 181               Windows 10    2.06            1    0  282.42
# 761               Windows 10    1.38            1    1  158.48
# 998               Windows 10    1.84            0    0  141.21
# 617               Windows 10    2.40            0    0  100.45
# ..                       ...     ...          ...  ...     ...
# 866               Windows 10    1.09            1    0  352.47
# 742               Windows 10    1.80            0    1  157.35
# 74                     No OS    2.20            0    0  141.21
# 176  Chrome OS/Linux/Android    2.02            0    0  141.21
# 338               Windows 10    1.88            0    0  141.21
#
# [1040 rows x 10 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
X_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram       Gpu       OpSys  Weight  \
# 921    Dell  Notebook  Intel Core i5    4  Intel HD  Windows 10     1.9
#
#      Touchscreen  IPS     ppi
# 921            0    0  100.45

# %%
X_test.sample()
# Out:
#     Company TypeName            Cpu  Ram             Gpu       OpSys  Weight  \
# 745    Asus   Gaming  Intel Core i7   16  Nvidia GeForce  Windows 10     4.3
#
#      Touchscreen  IPS     ppi
# 745            0    1  127.34

# %%
# LinearRegression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8427602549987014
# MAE: 0.20733053607895752
# MSE: 0.06921651281942114

# %%
# Lasso Regression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=Lasso(alpha=0.0001)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.841573411978544
# MAE: 0.2086994887378086
# MSE: 0.06973895792462459

# %%
# Ridge Regression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=Ridge(alpha=0.001)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.84275998831904
# MAE: 0.2073272509799408
# MSE: 0.06921663021109083

# %%
# KNeighborsRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=KNeighborsRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8389028505276447
# MAE: 0.20603307551685002
# MSE: 0.07091453189226042

# %%
# DecisionTreeRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=12)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8334351589208246
# MAE: 0.20040085465106453
# MSE: 0.07332139503104872

# %%
# SVR
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=SVR(C=10000)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8667385018575207
# MAE: 0.18744076764375636
# MSE: 0.058661353046826736

# %%
# RandomForestRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=RandomForestRegressor(n_estimators=100)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.887892138316057
# MAE: 0.1716647350348326
# MSE: 0.049349579175039036

# %%
# AdaBoostRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=AdaBoostRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8039358471618979
# MAE: 0.23852769707263616
# MSE: 0.08630691272257761

# %%
# XGBRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=XGBRegressor(n_estimators=30)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8912936689449227
# MAE: 0.168221698472655
# MSE: 0.0478522345413614

# %%
# GradientBoostingRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=GradientBoostingRegressor(n_estimators=500)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 Score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.8971180542433274
# MAE: 0.16372749349886762
# MSE: 0.04528835579894198

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# !pip install streamlit --quiet

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np

df=pickle.load(open('df.pkl','rb'))
pipe=pickle.load(open('pipe.pkl','rb'))

st.title("Laptop Price Predictor")

company=st.selectbox("Manufacturer",df['Company'].unique(),index=4)
type=st.selectbox("Type of the laptop",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Processor",df['Cpu'].unique(),index=0)
ram=st.selectbox("RAM(in GB)",[2,4,8,12,16,24,32,64,128],index=2)
gpu=st.selectbox('Graphics Card',df['Gpu'].unique(),index=1)
os=st.selectbox("Operating System",df['OpSys'].unique(),index=2)
weight=st.slider("Weight(in kg)",min_value=0.5,max_value=5.0,value=2.0,step=0.1)
touchscreen=st.selectbox("Does the laptop have touchscreen functionality?",['No','Yes'])
ips=st.selectbox("Does the laptop display have IPS Panel?",['No','Yes'],index=0)
screen_size=st.slider("Please state the screen size of the laptop(Measured diagonally).",
min_value=10.0,max_value=18.5,value=15.5,step=0.1)
screen_resolution=st.selectbox("Please mention the ScreenResolution of the same",
["2560x1600","1440x900","1920x1080","2880x1800","1366x768",
"2304x1440","3200x1800","1920x1200","2256x1504","3840x2160",
"2160x1440","2560x1440","1600x900","2736x1824","2400x1600"])
if st.button("PREDICT PRICE"):
    X_res=int(screen_resolution.split('x')[0])
    Y_res=int(screen_resolution.split('x')[1])
    ppi=round(((X_res**2)+(Y_res**2))**0.5/screen_size,2)
    if touchscreen=="No":
        touchscreen=0
    else:
        touchscreen=1
    if ips=="No":
        ips=0
    else:
        ips=1
    query=np.array([[company,type,cpu,ram,gpu,os,weight,touchscreen,ips,ppi]])
    op=pipe.predict(query)
    st.subheader("The laptop with above mentioned configuration will approximatey cost around ₹"+str(round(np.exp(op[0]))))
# Out:
# Overwriting app.py

# %%
X_train.sample()
# Out:
#      Company  TypeName            Cpu  Ram         Gpu       OpSys  Weight  \
# 1222      HP  Notebook  Intel Core i7    6  AMD Radeon  Windows 10    2.19
#
#       Touchscreen  IPS     ppi
# 1222            0    0  100.45

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.231.217.92:8501
#
# npx: installed 22 in 2.669s
# your url is: https://sour-bags-jog.loca.lt
